# %% [markdown]
# **Import Package and Library**

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, AveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping
from keras.preprocessing.image import load_img
import matplotlib.image as mpimg
import numpy as np

# %% [markdown]
# **Import Dataset**

# %%
# Paths to training and validation datasets
train_dir = 'dataset/train'

for root, dirs, files in os.walk(train_dir):
    print(root, dirs, files)
# Out:
# dataset/train ['Apple - Fresh', 'Mango - Fresh', 'Orange - Fresh'] []
# dataset/train\Apple - Fresh [] ['apple (1).jpeg', 'apple (10).jpeg', 'apple (100).jpeg', 'apple (101).jpeg', 'apple (102).jpeg', 'apple (103).jpeg', 'apple (104).jpeg', 'apple (105).jpeg', 'apple (106).jpeg', 'apple (107).jpeg', 'apple (108).jpeg', 'apple (109).jpeg', 'apple (11).jpeg', 'apple (110).jpeg', 'apple (111).jpeg', 'apple (112).jpeg', 'apple (113).jpeg', 'apple (114).jpeg', 'apple (115).jpeg', 'apple (116).jpeg', 'apple (117).jpeg', 'apple (118).jpeg', 'apple (119).jpeg', 'apple (12).jpeg', 'apple (120).jpeg', 'apple (121).jpeg', 'apple (122).jpeg', 'apple (123).jpeg', 'apple (124).jpeg', 'apple (125).jpeg', 'apple (126).jpeg', 'apple (127).jpeg', 'apple (128).jpeg', 'apple (129).jpeg', 'apple (13).jpeg', 'apple (130).jpeg', 'apple (131).jpeg', 'apple (132).jpeg', 'apple (133).jpeg', 'apple (134).jpeg', 'apple (135).jpeg', 'apple (136).jpeg', 'apple (137).jpeg', 'apple (138).jpeg', 'apple (139).jpeg', 'apple (14).jpeg', 'apple (140).jpeg', 'apple (141).jpeg', 'apple (142).jpeg', 'apple (143).jpeg', 'apple (144).jpeg', 'apple (145).jpeg', 'apple (146).jpeg', 'apple (147).jpeg', 'apple (148).jpeg', 'apple (149).jpeg', 'apple (15).jpeg', 'apple (150).jpeg', 'apple (151).jpeg', 'apple (152).jpeg', 'apple (153).jpeg', 'apple (154).jpeg', 'apple (155).jpeg', 'apple (156).jpeg', 'apple (157).jpeg', 'apple (158).jpeg', 'apple (159).jpeg', 'apple (16).jpeg', 'apple (160).jpeg', 'apple (161).jpeg', 'apple (162).jpeg', 'apple (163).jpeg', 'apple (164).jpeg', 'apple (165).jpeg', 'apple (166).jpeg', 'apple (167).jpeg', 'apple (168).jpeg', 'apple (169).jpeg', 'apple (17).jpeg', 'apple (170).jpeg', 'apple (171).jpeg', 'apple (172).jpeg', 'apple (173).jpeg', 'apple (174).jpeg', 'apple (175).jpeg', 'apple (176).jpeg', 'apple (177).jpeg', 'apple (178).jpeg', 'apple (179).jpeg', 'apple (18).jpeg', 'apple (180).jpeg', 'apple (181).jpeg', 'apple (182).jpeg', 'apple (183).jpeg', 'apple (184).jpeg', 'apple (185).jpeg', 'apple (186).jpeg', 'apple (187).jpeg', 'apple (188).jpeg', 'apple (189).jpeg', 'apple (19).jpeg', 'apple (190).jpeg', 'apple (191).jpeg', 'apple (192).jpeg', 'apple (193).jpeg', 'apple (194).jpeg', 'apple (195).jpeg', 'apple (196).jpeg', 'apple (197).jpeg', 'apple (198).jpeg', 'apple (199).jpeg', 'apple (2).jpeg', 'apple (20).jpeg', 'apple (200).jpeg', 'apple (201).jpeg', 'apple (202).jpeg',
jpeg', 'mango (60).jpeg', 'mango (61).jpeg', 'mango (62).jpeg', 'mango (63).jpeg', 'mango (64).jpeg', 'mango (65).jpeg', 'mango (66).jpeg', 'mango (67).jpeg', 'mango (68).jpeg', 'mango (69).jpeg', 'mango (7).jpeg', 'mango (70).jpeg', 'mango (71).jpeg', 'mango (72).jpeg', 'mango (73).jpeg', 'mango (74).jpeg', 'mango (75).jpeg', 'mango (76).jpeg', 'mango (77).jpeg', 'mango (78).jpeg', 'mango (79).jpeg', 'mango (8).jpeg', 'mango (80).jpeg', 'mango (81).jpeg', 'mango (82).jpeg', 'mango (83).jpeg' ...
# dataset/train\Orange - Fresh [] ['orange (1).jpeg', 'orange (10).jpeg', 'orange (100).jpeg', 'orange (101).jpeg', 'orange (102).jpeg', 'orange (103).jpeg', 'orange (104).jpeg', 'orange (105).jpeg', 'orange (106).jpeg', 'orange (107).jpeg', 'orange (108).jpeg', 'orange (109).jpeg', 'orange (11).jpeg', 'orange (110).jpeg', 'orange (111).jpeg', 'orange (112).jpeg', 'orange (113).jpeg', 'orange (114).jpeg', 'orange (115).jpeg', 'orange (116).jpeg', 'orange (117).jpeg', 'orange (118).jpeg', 'orange (119).jpeg', 'orange (12).jpeg', 'orange (120).jpeg', 'orange (121).jpeg', 'orange (122).jpeg', 'orange (123).jpeg', 'orange (124).jpeg', 'orange (125).jpeg', 'orange (126).jpeg', 'orange (127).jpeg', 'orange (128).jpeg', 'orange (129).jpeg', 'orange (13).jpeg', 'orange (130).jpeg', 'orange (131).jpeg', 'orange (132).jpeg', 'orange (133).jpeg', 'orange (134).jpeg', 'orange (135).jpeg', 'orange (136).jpeg', 'orange (137).jpeg', 'orange (138).jpeg', 'orange (139).jpeg', 'orange (14).jpeg', 'orange (140).jpeg', 'orange (141).jpeg', 'orange (142).jpeg', 'orange (143).jpeg', 'orange (144).jpeg', 'orange (145).jpeg', 'orange (146).jpeg', 'orange (147).jpeg', 'orange (148).jpeg', 'orange (149).jpeg', 'orange (15).jpeg', 'orange (150).jpeg', 'orange (151).jpeg', 'orange (152).jpeg', 'orange (153).jpeg', 'orange (154).jpeg', 'orange (155).jpeg', 'orange (156).jpeg', 'orange (157).jpeg', 'orange (158).jpeg', 'orange (159).jpeg', 'orange (16).jpeg', 'orange (160).jpeg', 'orange (161).jpeg', 'orange (162).jpeg', 'orange (163).jpeg', 'orange (164).jpeg', 'orange (165).jpeg', 'orange (166).jpeg', 'orange (167).jpeg', 'orange (168).jpeg', 'orange (169).jpeg', 'orange (17).jpeg', 'orange (170).jpeg', 'orange (171).jpeg', 'orange (172).jpeg', 'orange (173).jpeg', 'orange (174).jpeg', 'orange (175).jpeg', 'orange (176).jpeg', 'orange (177).jpeg', 'orange (178).jpeg', 'orange (179).jpeg', 'orange (18).jpeg', 'orange (180).jpeg', 'orange (181).jpeg', 'orange (182).jpeg', 'orange (183).jpeg', 'orange (184).jpeg', 'orange (185).jpeg', 'orange (186).jpeg', 'orange (187).jpeg', 'orange (188).jpeg', 'orange (189).jpeg', 'orange (19).jpeg', 'orange (190).jpeg', 'orange (191).jpeg', 'orange (192).jpeg', 'orange (193).jpeg', 'orange (194).jpeg', 'orange (195).jpeg', 'orange (196).jpeg', 'orange (197).jpeg', 'orange (198).jpeg', 'orange (199).jpeg', 'orange (2).jpeg', 'orange (20).jpeg', 'orange (200).jpeg', 'orange (201).jpeg', 'orange (202).jpeg', 'orange (203).jpeg', 'orange (204).jpeg', 'orange (205).jpeg', 'orange (206).jpeg', 'orange (207).jpeg', 'orange (208).jpeg', 'orange (209).jpeg', 'orange (21).jpeg', 'orange (210).jpeg', 'orange (211).jpeg', 'orange (212).jpeg', 'orange (213).jpeg', 'orange (214).jpeg', 'orange (215).jpeg', 'orange (216).jpeg', 'orange (217).jpeg', 'orange (218).jpeg', 'orange (219).jpeg', 'orange (22).jpeg', 'orange (220).jpeg', 'orange (23).jpeg', 'orange (24).jpeg', 'orange (25).jpeg', 'orange (26).jpeg', 'orange (27).jpeg', 'orange (28).jpeg', 'orange (29).jpeg', 'orange (3).jpeg', 'orange (30).jpeg', 'orange (31).jpeg', 'orange (32).jpeg', 'orange (33).jpeg', 'orange (34).jpeg', 'orange (35).jpeg', 'orange (36).jpeg', 'orange (37).jpeg', 'orange (38).jpeg', 'orange (39).jpeg', 'orange (4).jpeg', 'orange (40).jpeg', 'orange (41).jpeg', 'orange (42).jpeg', 'orange (43).jpeg', 'orange (44).jpeg', 'orange (45).jpeg', 'orange (46).jpeg', 'orange (47).jpeg', 'orange (48).jpeg', 'orange (49).jpeg', 'orange (5).jpeg', 'orange (50).jpeg', 'orange (51).jpeg', 'orange (52).jpeg', 'orange (53).jpeg', 'orange (54).jpeg', 'orange (55).jpeg', 'orange (56).jpeg', 'orange (57).jpeg', 'orange (58).jpeg', 'orange (59).jpeg', 'orange (6).jpeg', 'orange (60).jpeg', 'orange (61).jpeg', 'orange (62).jpeg', 'orange (63).jpeg', 'orange (64).jpeg', 'orange (65).jpeg', 'orange (66).jpeg', 'orange (67).jpeg', 'orange (68).jpeg', 'orange (69).jpeg', 'orange (7).jpeg', 'orange (70).jpeg', 'orange (71).jpeg', 'orange (72).jpeg', 'orange (73).jpeg', 'orange (74). ...

# %%
validation_dir = 'dataset/validation'

for root, dirs, files in os.walk(validation_dir):
    print(root, dirs, files)
# Out:
# dataset/validation ['Apple - Fresh', 'Mango - Fresh', 'Orange - Fresh'] []
# dataset/validation\Apple - Fresh [] ['apple (1).jpeg', 'apple (10).jpeg', 'apple (11).jpeg', 'apple (12).jpeg', 'apple (13).jpeg', 'apple (14).jpeg', 'apple (15).jpeg', 'apple (16).jpeg', 'apple (17).jpeg', 'apple (18).jpeg', 'apple (19).jpeg', 'apple (2).jpeg', 'apple (20).jpeg', 'apple (21).jpeg', 'apple (22).jpeg', 'apple (23).jpeg', 'apple (24).jpeg', 'apple (25).jpeg', 'apple (26).jpeg', 'apple (27).jpeg', 'apple (28).jpeg', 'apple (29).jpeg', 'apple (3).jpeg', 'apple (30).jpeg', 'apple (31).jpeg', 'apple (32).jpeg', 'apple (33).jpeg', 'apple (34).jpeg', 'apple (35).jpeg', 'apple (36).jpeg', 'apple (37).jpeg', 'apple (38).jpeg', 'apple (39).jpeg', 'apple (4).jpeg', 'apple
g', 'orange (40).jpeg', 'orange (41).jpeg', 'orange (42).jpeg', 'orange (43).jpeg', 'orange (44).jpeg', 'orange (45).jpeg', 'orange (46).jpeg', 'orange (47).jpeg', 'orange (48).jpeg', 'orange (49).jpeg', 'orange (5).jpeg', 'orange (50).jpeg', 'orange (51).jpeg', 'orange (52).jpeg', 'orange (53).jpeg', 'orange (54).jpeg', 'orange (55).jpeg', 'orange (56).jpeg', 'orange (57).jpeg', 'orange (58).jpeg', 'orange (59).jpeg', 'orange (6).jpeg', 'orange (60).jpeg', 'orange (61).jpeg', 'orange (62).jpeg', 'orange (63).jpeg', 'orange (64).jpeg', 'orange (65).jpeg', 'orange (66).jpeg', 'orange (67).jpeg', 'orange (68).jpeg', 'orange (69).jpeg', 'orange (7).jpeg', 'orange (70).jpeg', 'orange (8).jpeg', 'orange (9).jpeg']

# %%
test_dir = 'dataset/test'

for root, dirs, files in os.walk(test_dir):
    print(root, dirs, files)
# Out:
# dataset/test [] ['apple (1).png', 'apple (2).png', 'apple (3).png', 'mango (1).jpeg', 'mango (2).jpeg', 'mango (3).jpeg', 'orange (1).png', 'orange (2).png', 'orange (3).png']

# %% [markdown]
# **Display Dataset**

# %%
def count_images_in_folder(folder_path):
    count_dict = {}

    for subfolder in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder)

        if os.path.isdir(subfolder_path):
            num_files = len(os.listdir(subfolder_path))
            count_dict[subfolder] = num_files
    return count_dict

def print_image_counts(base_dir):
    for split in ['train', 'validation']:
        folder_path = os.path.join(base_dir, split)
        print(f"Menghitung gambar pada {split} folder:")
        count_dict = count_images_in_folder(folder_path)

        total_images = sum(count_dict.values())
        print(f"Jumlah gambar pada {split} folder: {total_images}")

        for subfolder, count in count_dict.items():
            print(f"  {subfolder}: {count} images")
        print()

base_dir = 'dataset'

print_image_counts(base_dir)
# Out:
# Menghitung gambar pada train folder:
# Jumlah gambar pada train folder: 660
#   Apple - Fresh: 220 images
#   Mango - Fresh: 220 images
#   Orange - Fresh: 220 images
#
# Menghitung gambar pada validation folder:
# Jumlah gambar pada validation folder: 200
#   Apple - Fresh: 60 images
#   Mango - Fresh: 70 images
#   Orange - Fresh: 70 images

# %%
# Function to display a single image from each class
def show_sample_image(image_dir, class_name):
    image_files = os.listdir(image_dir)
    
    image_path = os.path.join(image_dir, image_files[0])
    img = mpimg.imread(image_path)
    plt.imshow(img)
    plt.title(class_name)
    plt.axis('off')

# Displaying one image from each class
plt.figure(figsize=(5, 5))  

plt.subplot(2, 3, 1)
show_sample_image('dataset/train/Apple - Fresh', 'Train - Apple')

plt.subplot(2, 3, 2)
show_sample_image('dataset/train/Mango - Fresh', 'Train - Mango')

plt.subplot(2, 3, 3)
show_sample_image('dataset/train/Orange - Fresh', 'Train - Orange')

plt.subplot(2, 3, 4)
show_sample_image('dataset/validation/Apple - Fresh', 'Validation - Apple')

plt.subplot(2, 3, 5)
show_sample_image('dataset/validation/Mango - Fresh', 'Validation - Mango')

plt.subplot(2, 3, 6)
show_sample_image('dataset/validation/Orange - Fresh', 'Validation - Orange')

plt.tight_layout()  # Adjust subplot layout to prevent overlap
plt.show()

# %% [markdown]
# **Make Data Generator**

# %%
# data augmentation generator for the training data
train_datagen = ImageDataGenerator(rescale = 1./255,
                             rotation_range=40,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale = 1./255)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_ds = train_datagen.flow_from_directory(
    directory = train_dir,
    batch_size = 32,
    target_size = (224, 224),
    class_mode = 'categorical'
)
# Out:
# Found 660 images belonging to 3 classes.

# %%
validation_ds = val_datagen.flow_from_directory(
    directory = validation_dir,
    batch_size = 32,
    target_size = (224, 224),
    class_mode = 'categorical'
)
# Out:
# Found 200 images belonging to 3 classes.

# %%
x_batch, y_batch = next(train_ds)
print(x_batch.shape, y_batch.shape)
# Out:
# (32, 224, 224, 3) (32, 3)

# %% [markdown]
# **Use Pre-Trained Model MobileNetV2**

# %%
# Load the pre-trained EfficientNetB4 model without the top classification layer
MobileNetV2_base = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3),
                              pooling='avg')

# Freeze the pre-trained base model layers
MobileNetV2_base.trainable = False

# %% [markdown]
# **Build Neural Network Model**

# %%
# Add new layers on top of the base model
inputs = tf.keras.Input(shape=(224, 224, 3))
x = MobileNetV2_base(inputs, training=False)
x = BatchNormalization()(x)
x = Dropout(0.35)(x)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
outputs = Dense(3, activation='softmax')(x)

# Define the new model
model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,435,523 (9.29 MB)
#  Trainable params: 174,979 (683.51 KB)
#  Non-trainable params: 2,260,544 (8.62 MB)

# %% [markdown]
# **Compile Model**

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# **Train Model**

# %%
batch_size = 32

history= model.fit(
    train_ds,
    validation_data=validation_ds,
    steps_per_epoch=len(train_ds) // batch_size,
    epochs=35
)
# Out:
# Epoch 1/35
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.3605 - loss: 2.0891 - val_accuracy: 0.4300 - val_loss: 1.3344
# Epoch 2/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 909ms/step - accuracy: 0.4644 - loss: 1.3100 - val_accuracy: 0.5850 - val_loss: 0.9364
# Epoch 3/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 964ms/step - accuracy: 0.6103 - loss: 0.8376 - val_accuracy: 0.6600 - val_loss: 0.7401
# Epoch 4/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 22s 930ms/step - accuracy: 0.7472 - loss: 0.6430 - val_accuracy: 0.7600 - val_loss: 0.6262
# Epoch 5/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 22s 908ms/step - accuracy: 0.7800 - loss: 0.5430 - val_accuracy: 0.8050 - val_loss: 0.5531
# Epoch 6/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 940ms/step - accuracy: 0.7846 - loss: 0.5180 - val_accuracy: 0.8100 - val_loss: 0.5023
# Epoch 7/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 921ms/step - accuracy: 0.7987 - loss: 0.4967 - val_accuracy: 0.8400 - val_loss: 0.4646
# Epoch 8/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 894ms/step - accuracy: 0.8681 - loss: 0.3902 - val_accuracy: 0.8600 - val_loss: 0.4332
# Epoch 9/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 22s 910ms/step - accuracy: 0.8785 - loss: 0.3413 - val_accuracy: 0.8800 - val_loss: 0.4040
# Epoch 10/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 888ms/step - accuracy: 0.8613 - loss: 0.3725 - val_accuracy: 0.8850 - val_loss: 0.3860
# Epoch 11/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.8404 - loss: 0.3645 - val_accuracy: 0.9000 - val_loss: 0.3747
# Epoch 12/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.8862 - loss: 0.3196 - val_accuracy: 0.9100 - val_loss: 0.3566
# Epoch 13/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9019 - loss: 0.2745 - val_accuracy: 0.9150 - val_loss: 0.3398
# Epoch 14/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.8899 - loss: 0.3131 - val_accuracy: 0.9100 - val_loss: 0.3266
# Epoch 15/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8763 - loss: 0.3177 - val_accuracy: 0.9150 - val_loss: 0.3214
# Epoch 16/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 987ms/step - accuracy: 0.8941 - loss: 0.2787 - val_accuracy: 0.9150 - val_loss: 0.3188
# Epoch 17/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 978ms/step - accuracy: 0.9097 - loss: 0.2272 - val_accuracy: 0.9100 - val_loss: 0.3087
# Epoch 18/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 871ms/step - accuracy: 0.8944 - loss: 0.2620 - val_accuracy: 0.9250 - val_loss: 0.2933
# Epoch 19/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 919ms/step - accuracy: 0.9185 - loss: 0.2332 - val_accuracy: 0.9250 - val_loss: 0.2919
# Epoch 20/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 22s 895ms/step - accuracy: 0.9093 - loss: 0.2274 - val_accuracy: 0.9100 - val_loss: 0.2927
# Epoch 21/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 864ms/step - accuracy: 0.9232 - loss: 0.2179 - val_accuracy: 0.9100 - val_loss: 0.2934
# Epoch 22/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 862ms/step - accuracy: 0.9314 - loss: 0.2424 - val_accuracy: 0.9200 - val_loss: 0.2904
# Epoch 23/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 904ms/step - accuracy: 0.9399 - loss: 0.2031 - val_accuracy: 0.9200 - val_loss: 0.2865
# Epoch 24/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 22s 889ms/step - accuracy: 0.9241 - loss: 0.2027 - val_accuracy: 0.9200 - val_loss: 0.2809
# Epoch 25/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 856ms/step - accuracy: 0.9324 - loss: 0.2048 - val_accuracy: 0.9250 - val_loss: 0.2782
# Epoch 26/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9431 - loss: 0.1742 - val_accuracy: 0.9200 - val_loss: 0.2768
# Epoch 27/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9463 - loss: 0.1597 - val_accuracy: 0.9200 - val_loss: 0.2757
# Epoch 28/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9517 - loss: 0.1365 - val_accuracy: 0.9300 - val_loss: 0.2760
# Epoch 29/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9186 - loss: 0.1887 - val_accuracy: 0.9300 - val_loss: 0.2702
# Epoch 30/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 857ms/step - accuracy: 0.9322 - loss: 0.1697 - val_accuracy: 0.9300 - val_loss: 0.2700
# Epoch 31/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 847ms/step - accuracy: 0.9387 - loss: 0.1767 - val_accuracy: 0.9300 - val_loss: 0.2614
# Epoch 32/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 862ms/step - accuracy: 0.9558 - loss: 0.1500 - val_accuracy: 0.9300 - val_loss: 0.2622
# Epoch 33/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 847ms/step - accuracy: 0.9557 - loss: 0.1398 - val_accuracy: 0.9350 - val_loss: 0.2629
# Epoch 34/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 883ms/step - accuracy: 0.9490 - loss: 0.1755 - val_accuracy: 0.9300 - val_loss: 0.2591
# Epoch 35/35
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9449 - loss: 0.1457 - val_accuracy: 0.9350 - val_loss: 0.2611

# %% [markdown]
# **Evaluate Model**

# %%
# evaluate the model
loss, model_accuracy = model.evaluate(validation_ds)

print(f'Model accuracy: {model_accuracy}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 519ms/step - accuracy: 0.9246 - loss: 0.2773
# Model accuracy: 0.9350000023841858

# %%
# Plotting the training and testing loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# Plotting the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %% [markdown]
# **Save Model**

# %%
model.save('freshness-condition.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# **Testing**

# %%
#labels
class_names = list(train_ds.class_indices.keys())
print(class_names)
# Out:
# ['Apple - Fresh', 'Mango - Fresh', 'Orange - Fresh']

# %%
# Tampilkan prediksi dan percentage
def predict_class(image_path):
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0

    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions)]
    percentage = np.max(predictions)*100
    f_percentage = f"{percentage:.2f}%"
    return predicted_class, f_percentage

# Tampilkan gambar input bersamaan dengan hasil prediksi
def display_prediction(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {predict_class(img_path)}")
    plt.show()

# %%
image_path = 'dataset/test/mango (3).jpeg'
display_prediction(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
image_path = 'dataset/test/apple (2).png'
display_prediction(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
image_path = 'dataset/test/orange (2).png'
display_prediction(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
